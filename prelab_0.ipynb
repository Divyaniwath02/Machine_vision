# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyaniwath02/Machine_vision/blob/main/prelab_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================================
# Step 1: Install Required Libraries
# ==========================================================

# !pip install opencv-python numpy matplotlib

import cv2
import numpy as np
import matplotlib.pyplot as plt

print("OpenCV Version:", cv2.__version__)
print("NumPy Installed")
print("Matplotlib Installed")
# Out:
# ...
# OpenCV Version: 4.13.0
# NumPy Installed
# Matplotlib Installed

# %%
from google.colab import files

uploaded = files.upload()

# Replace image name if different
image = cv2.imread(list(uploaded.keys())[0])

print("Image Loaded Successfully")
# Out:
#      <input type="file" id="files-5f948cf9-54b2-47c8-a6b3-308e8dbbf459" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f948cf9-54b2-47c8-a6b3-308e8dbbf459">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Convert BGR → RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.title("Loaded Image")
plt.axis("off")
plt.show()

# %%
print("Image Shape:", image.shape)
print("Height:", image.shape[0])

print("Width:", image.shape[1])

print("Channels:", image.shape[2])

print("Data Type:", image.dtype)
# Out:
# Image Shape: (720, 1280, 3)
# Height: 720
# Width: 1280
# Channels: 3
# Data Type: uint8

# %%
# Split channels
B, G, R = cv2.split(image)

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(B, cmap='gray')
plt.title("Blue Channel")

plt.subplot(1,3,2)
plt.imshow(G, cmap='gray')
plt.title("Green Channel")

plt.subplot(1,3,3)
plt.imshow(R, cmap='gray')
plt.title("Red Channel")

plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')
plt.title("Gray Image")
plt.axis("off")
plt.show()
